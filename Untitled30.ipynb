# %% [markdown]
# ## Q1. What is the Probability density function?

# %% [markdown]
# The Probability Density Function (PDF) is a concept in probability theory and statistics. It describes the likelihood of a continuous random variable falling within a particular range of values. In essence, the PDF gives the probability of the variable taking on a specific value or falling within a specific interval.
#
# For a continuous random variable
# �
# X, the PDF is denoted by
# �
# (
# �
# )
# f(x), where
# �
# (
# �
# )
# f(x) represents the function that assigns probabilities to different outcomes. The PDF satisfies the following properties:
#
# The probability that
# �
# X falls in some interval
# [
# �
# ,
# �
# ]
# [a,b] is given by the integral of
# �
# (
# �
# )
# f(x) over that interval:
# �
# (
# �
# ≤
# �
# ≤
# �
# )
# =
# ∫
# �
# �
# �
# (
# �
# )
#
# �
# �
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
#
# �
# (
# �
# )
# f(x) must be non-negative for all
# �
# x.
#
# The total area under the curve of the PDF is equal to 1:
# ∫
# −
# ∞
# ∞
# �
# (
# �
# )
#
# �
# �
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
#
# The PDF is a fundamental concept in probability and statistics, particularly in fields like inferential statistics, where it's used to describe the distribution of continuous random variables such as normal, exponential, and uniform distributions, among others.

# %% [markdown]
# ## Q2. What are the types of Probability distribution?
